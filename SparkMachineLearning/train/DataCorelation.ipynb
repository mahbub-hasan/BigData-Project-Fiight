# %%
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt

# %%
df = pd.read_csv('/Users/mahbubhasan/Desktop/BigData-Project-Fiight/SparkMachineLearning/train/part-00000-ba289828-8996-4b2a-a55c-e92385b2a60d-c000.csv')
df
# Out:
#         airline  month day_of_the_week    source  source_busy destination  \
# 0      Air Asia  March          Friday  Banglore            1   New Delhi
# 1      Air Asia  March          Friday  Banglore            1   New Delhi
# 2      Air Asia  March          Sunday  Banglore            1   New Delhi
# 3      Air Asia  March          Sunday  Banglore            1   New Delhi
# 4      Air Asia  March          Sunday  Banglore            1   New Delhi
# ...         ...    ...             ...       ...          ...         ...
# 10457   Vistara   June          Sunday   Kolkata            1    Banglore
# 10458   Vistara   June          Sunday   Kolkata            1    Banglore
# 10459   Vistara   June          Sunday   Kolkata            1    Banglore
# 10460   Vistara   June          Sunday   Kolkata            1    Banglore
# 10461   Vistara   June          Sunday   Kolkata            1    Banglore
#
#        destination_busy dep_timeZone arrival_timeZone  duration  total_stops  \
# ...

# %%
df.loc[(df['dep_timeZone']=='morning') & (df['arrival_timeZone']=='morning')]
# Out:
#          airline  month day_of_the_week    source  source_busy destination  \
# 326    Air India  March          Friday  Banglore            1   New Delhi
# 331    Air India  March          Friday  Banglore            1   New Delhi
# 332    Air India  March          Friday  Banglore            1   New Delhi
# 339    Air India  March          Friday  Banglore            1   New Delhi
# 356    Air India  March          Friday  Banglore            1   New Delhi
# ...          ...    ...             ...       ...          ...         ...
# 9968    SpiceJet   June          Sunday   Kolkata            1    Banglore
# 9969    SpiceJet   June          Sunday   Kolkata            1    Banglore
# 10251    Vistara  March          Sunday   Kolkata            1    Banglore
# 10353    Vistara  March       Wednesday    Mumbai            1   Hyderabad
# 10358    Vistara  March       Wednesday    Mumbai            1   Hyderabad
#
# ...

# %%
df[['duration','total_stops','busy_Intermediate','price']]
# Out:
#        duration  total_stops  busy_Intermediate    price
# 0           170            0                  0  10715.0
# 1           165            0                  0  10873.0
# 2           170            0                  0   7074.0
# 3           170            0                  0   7652.0
# 4           165            0                  0   6135.0
# ...         ...          ...                ...      ...
# 10457       385            1                  1   9870.0
# 10458       865            1                  1   9397.0
# 10459      1350            1                  1   8610.0
# 10460      1440            1                  1   8085.0
# 10461      1625            1                  1   8085.0
#
# [10462 rows x 4 columns]

# %%
df.total_stops.values.max()
# Out:
# 4

# %%
df.head(1000)
# Out:
#        airline  month day_of_the_week    source  source_busy destination  \
# 0     Air Asia  March          Friday  Banglore            1   New Delhi
# 1     Air Asia  March          Friday  Banglore            1   New Delhi
# 2     Air Asia  March          Sunday  Banglore            1   New Delhi
# 3     Air Asia  March          Sunday  Banglore            1   New Delhi
# 4     Air Asia  March          Sunday  Banglore            1   New Delhi
# ..         ...    ...             ...       ...          ...         ...
# 995  Air India    May        Saturday   Kolkata            1    Banglore
# 996  Air India    May        Saturday   Kolkata            1    Banglore
# 997  Air India    May        Saturday   Kolkata            1    Banglore
# 998  Air India    May        Saturday   Kolkata            1    Banglore
# 999  Air India    May        Saturday   Kolkata            1    Banglore
#
#      destination_busy   dep_timeZone arrival_timeZone  duration  total_stops  \
# ...

# %%
plt.figure(figsize=(15,8))
sns.heatmap(df.corr(), cmap="Greens",annot=True)
# Out:
# <AxesSubplot: >

# %%
df_new = df[['airline','month','day_of_the_week','destination_busy','dep_timeZone','arrival_timeZone','duration','total_stops','busy_Intermediate','price']]

# %%
df_new.month.values.min()
# Out:
# 0

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
df_new.airline = le.fit_transform(df_new.airline)
df_new.month = le.fit_transform(df_new.month)
df_new.day_of_the_week = le.fit_transform(df_new.day_of_the_week)
df_new.dep_timeZone = le.fit_transform(df_new.dep_timeZone)
df_new.arrival_timeZone = le.fit_transform(df_new.arrival_timeZone)
# Out:
# /var/folders/1y/9s51hsw94wq1k4w2hgvd0qdc0000gn/T/ipykernel_36394/430114833.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_new.airline = le.fit_transform(df_new.airline)
# /var/folders/1y/9s51hsw94wq1k4w2hgvd0qdc0000gn/T/ipykernel_36394/430114833.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_new.month = le.fit_transform(df_new.month)
# /var/folders/1y/9s51hsw94wq1k4w2hgvd0qdc0000gn/T/ipykernel_36394/430114833.py:3: SettingWithCopyWarning:
# ...

# %%
df_new.destination_busy.values.min()
# Out:
# 0

# %%
plt.figure(figsize=(15,8))
sns.heatmap(df_new.corr(), cmap="Greens",annot=True)
# Out:
# <AxesSubplot: >
